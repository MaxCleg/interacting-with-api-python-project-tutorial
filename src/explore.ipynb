# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()

df = pd.read_csv("/workspaces/interacting-with-api-python-project-tutorial/linkin_park_top10.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre          10 non-null     object
#  1   Popularidad     10 non-null     int64
#  2   Duración (min)  10 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
df.sample(10)
# Out:
#                   Nombre  Popularidad  Duración (min)
# 6     Heavy Is the Crown           82            2.78
# 4     Up From the Bottom           85            3.05
# 1             In the End           89            3.61
# 2  The Emptiness Machine           85            3.17
# 3                  Faint           86            2.70
# 0                   Numb           90            3.13
# 8     Somewhere I Belong           76            3.57
# 5        One Step Closer           85            2.62
# 9               Crawling           82            3.48
# 7         What I've Done           84            3.42

# %%
#Gráfica de popularidad
plt.figure(figsize=(10, 6))
plt.barh(df["Nombre"], df["Popularidad"], color="green")
plt.xlabel("Popularidad")
plt.title("Top 10 Canciones de Linkin Park")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# No existe una relación como tal entre el tiempo de las canciones y su popularidad
